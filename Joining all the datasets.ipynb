# %%
import pandas as pd
import numpy as np

# %%
df_t=pd.read_csv('test_new.csv',sep=",")

# %%
df_30k=pd.read_csv('30000_submit.csv',sep=",")
df_30k_70k=pd.read_csv('30000_70000_submit.csv',sep=",")
df_70k_1lk=pd.read_csv('70000_100000_submit.csv',sep=",")
df_1lk_1lk50t=pd.read_csv('100000_150000_submit.csv',sep=",")
df_1lk50t_2lk=pd.read_csv('150000_200000_submit.csv',sep=",")
df_2lk_2lk50t=pd.read_csv('200000_250000_submit.csv',sep=",")
df_2lk50t_3lk=pd.read_csv('250000_300000_submit.csv',sep=",")
df_3lk_3lk60t=pd.read_csv('300000_360000_submit.csv',sep=",")
df_3lk60t_4lk20t=pd.read_csv('360000_420000_submit.csv',sep=",")
df_4lk20t_4lk51t=pd.read_csv('420000_451346_submit.csv',sep=",")

# %%
print(len(df_t))
print('*******')
print("\n")
print("\n")
print(len(df_30k))
print(len(df_30k_70k))
print(len(df_70k_1lk))
print(len(df_1lk_1lk50t))
print(len(df_1lk50t_2lk))
print(len(df_2lk_2lk50t))
print(len(df_2lk50t_3lk))
print(len(df_3lk_3lk60t))
print(len(df_3lk60t_4lk20t))
print(len(df_4lk20t_4lk51t))
# Out:
# 194323
# *******
#
#
#
#
# 194323
# 194323
# 194323
# 194323
# 194323
# 194323
# 194323
# 194323
# 194323
# 194323

# %% [raw]
# df_30k=[]
# df_30k_70k=[]
# df_70k_1lk=[]
# df_1lk_1lk50t=[]
# df_1lk50t_df_2lk=[]
# df_2lk_2lk50t=[]
# df_2lk50t_3lk=[]
# df_3lk_3lk60t=[]
# df_3lk60t_4lk20t=[]
# df_4lk20t_4lk51t=[]

# %%
a_df_30k=[]
a_df_30k_70k=[]
a_df_70k_1lk=[]
a_df_1lk_1lk50t=[]
a_df_1lk50t_2lk=[]
a_df_2lk_2lk50t=[]
a_df_2lk50t_3lk=[]
a_df_3lk_3lk60t=[]
a_df_3lk60t_4lk20t=[]
a_df_4lk20t_4lk51t=[]




for i in range(194323):
    
    a=str(df_30k['tags'][i])
    a=a.split('|')
    a_df_30k.append(a)
    
    b=str(df_30k_70k['tags'][i])
    b=b.split('|')
    a_df_30k_70k.append(b)
    
    c=str(df_70k_1lk['tags'][i])
    c=c.split('|')
    a_df_70k_1lk.append(c)
    
    d=str(df_1lk_1lk50t['tags'][i])
    d=d.split('|')
    a_df_1lk_1lk50t.append(d)
    
    e=str(df_1lk50t_2lk['tags'][i])
    e=e.split('|')
    df_1lk50t_2lk.append(e)
    
    
    f=str(df_2lk_2lk50t['tags'][i])
    f=f.split('|')
    a_df_2lk_2lk50t.append(f)
    
    
    g=str(df_2lk50t_3lk['tags'][i])
    g=g.split('|')
    a_df_2lk50t_3lk.append(g)
    
    h=str(df_3lk_3lk60t['tags'][i])
    h=h.split('|')
    a_df_3lk_3lk60t.append(h)
    
    j=str(df_3lk60t_4lk20t['tags'][i])
    j=j.split('|')
    a_df_3lk60t_4lk20t.append(j)
    
    k=str(df_4lk20t_4lk51t['tags'][i])
    k=k.split('|')
    a_df_4lk20t_4lk51t.append(k)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\api.py:107: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   result = result.union(other)

# %%
print(len(a_df_30k))
print(len(a_df_30k_70k))
print(len(a_df_70k_1lk))
print(len(a_df_1lk_1lk50t))
print(len(df_1lk50t_2lk))
print(len(a_df_2lk_2lk50t))
print(len(a_df_2lk50t_3lk))
print(len(a_df_3lk_3lk60t))
print(len(a_df_3lk60t_4lk20t))
print(len(a_df_4lk20t_4lk51t))
# Out:
# 194323
# 194323
# 194323
# 194323
# 194323
# 194323
# 194323
# 194323
# 194323
# 194323

# %%
# Out:
# [['nan'],
#  ['nan'],
#  ['nan'],
#  ['select'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['silverlight'],
#  ['nan'],
#  ['android'],
#  ['android'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['java', 'regex'],
#  ['perl'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['wpf'],
#  ['jquery'],
#  ['nan'],
#  ['django'],
#  ['python'],
#  ['nan'],
#  ['spring'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['jquery'],
#  ['mysql'],
#  ['svn'],
#  ['r'],
#  ['sqlite'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['angular'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['jquery'],
#  ['sql-server'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['swift'],
#  ['css', 'jquery'],
#  ['google-chrome'],
#  ['.net', 'c#'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['arrays'],
#  ['nan'],
#  ['arrays', 'c++'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['spring'],
# ...
